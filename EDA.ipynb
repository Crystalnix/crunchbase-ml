# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint
seaborn.set(style="whitegrid", color_codes=True)
# %matplotlib inline

# %%
data = pd.read_csv('/home/artem/Projects/wolf_of_crunchbase/data.csv')
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2683: DtypeWarning: Columns (6,13,15,16,17,24,39,44,59,64,69,74,79,84,94,99,104,109,114) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# <H3>Data preparation</H3>

# %% [markdown]
# <H4>Set ipo information to NaN if ipo was after acquisition</H4>

# %%
ipo_fields = ['ipo_id', 'valuation_amount', 'valuation_currency_code', 'raised_amount', 'raised_currency_code', 
              'public_at', 'stock_symbol']
ipo = pd.DataFrame({'ipo': data.public_at, 'acquired': data.acquired_at})
ipo.dropna(how='any', inplace=True)
ipo.loc[:, 'ipo'] = ipo.ipo.apply(pd.to_datetime)
ipo.loc[:, 'acquired'] = ipo.acquired.apply(pd.to_datetime)
ipo['ipo_after_acquired'] = (ipo['ipo'] - ipo['acquired']).apply(lambda x: x.days > 0)
indexes = ipo[ipo['ipo_after_acquired'] == True].index
data.loc[indexes, ipo_fields] = np.nan

# %% [markdown]
# <H4>Set closed_at to NaN if closed after acquisition</H4>

# %%
closed = pd.DataFrame({'closed': data.closed_at, 'acquired': data.acquired_at})
closed.dropna(how='any', inplace=True)
closed.loc[:, 'closed'] = closed.closed.apply(pd.to_datetime)
closed.loc[:, 'acquired'] = closed.acquired.apply(pd.to_datetime)
closed['closed_after_acquired'] = (closed['closed'] - closed['acquired']).apply(lambda x: x.days > 0)
indexes = closed[closed['closed_after_acquired'] == True].index
data.loc[indexes, 'closed_at'] = np.nan

# %% [markdown]
# <H4>Remove extra data and make some features</H4>

# %%
data['ipo'] = data.ipo_id.notnull()
data['is_acquired'] = data.acquired_at.notnull()
data['is_closed'] = data.closed_at.notnull()
data['age'] = (pd.to_datetime('2014-01-01') - pd.to_datetime(data['founded_at'])).apply(lambda x: x.days)
data.loc[:, 'category_code'] = data.category_code.astype('category')
columns_to_drop = ['Unnamed: 0', 'name', 'company_id', 'ipo_id', 'founded_at', 'closed_at']
data.drop(columns_to_drop, inplace=True, axis=1)

# %% [markdown]
# <H3>Columns in data file</H3>

# %%
for column in data.columns:
    print(column)
# Out:
# category_code
# status
# country_code
# state_code
# city
# region
# valuation_amount
# valuation_currency_code
# raised_amount
# raised_currency_code
# public_at
# stock_symbol
# acquired_at
# b_funded_at
# b_raised_amount_usd
# b_pre_money_valuation_usd
# b_post_money_valuation_usd
# b_participants
# angel_funded_at
# angel_raised_amount_usd
# angel_pre_money_valuation_usd
# angel_post_money_valuation_usd
# angel_participants
# a_funded_at
# a_raised_amount_usd
# a_pre_money_valuation_usd
# a_post_money_valuation_usd
# a_participants
# seed_funded_at
# seed_raised_amount_usd
# seed_pre_money_valuation_usd
# seed_post_money_valuation_usd
# seed_participants
# c_funded_at
# c_raised_amount_usd
# c_pre_money_valuation_usd
# c_post_money_valuation_usd
# c_participants
# d_funded_at
# d_raised_amount_usd
# d_pre_money_valuation_usd
# d_post_money_valuation_usd
# d_participants
# unattributed_funded_at
# unattributed_raised_amount_usd
# unattributed_pre_money_valuation_usd
# unattributed_post_money_valuation_usd
# unattributed_participants
# debt_round_funded_at
# debt_round_raised_amount_usd
# debt_round_pre_money_valuation_usd
# debt_round_post_money_valuation_usd
# debt_round_participants
# e_funded_at
# e_raised_amount_usd
# e_pre_money_valuation_usd
# e_post_money_valuation_usd
# e_participants
# f_funded_at
# f_raised_amount_usd
# f_pre_money_valuation_usd
# f_post_money_valuation_usd
# f_participants
# private_equity_funded_at
# private_equity_raised_amount_usd
# private_equity_pre_money_valuation_usd
# private_equity_post_money_valuation_usd
# private_equity_participants
# grant_funded_at
# grant_raised_amount_usd
# grant_pre_money_valuation_usd
# grant_post_money_valuation_usd
# grant_participants
# post_ipo_equity_funded_at
# post_ipo_equity_raised_amount_usd
# post_ipo_equity_pre_money_valuation_usd
# post_ipo_equity_post_money_valuation_usd
# post_ipo_equity_participants
# post_ipo_debt_funded_at
# post_ipo_debt_raised_amount_usd
# post_ipo_debt_pre_money_valuation_usd
# post_ipo_debt_post_money_valuation_usd
# post_ipo_debt_participants
# partial_funded_at
# partial_raised_amount_usd
# partial_pre_money_valuation_usd
# partial_post_money_valuation_usd
# partial_participants
# convertible_funded_at
# convertible_raised_amount_usd
# convertible_pre_money_valuation_usd
# convertible_post_money_valuation_usd
# convertible_participants
# crowd_funded_at
# crowd_raised_amount_usd
# crowd_pre_money_valuation_usd
# crowd_post_money_valuation_usd
# crowd_participants
# g_funded_at
# g_raised_amount_usd
# g_pre_money_valuation_usd
# g_post_money_valuation_usd
# g_participants
# secondary_market_funded_at
# secondary_market_raised_amount_usd
# secondary_market_pre_money_valuation_usd
# secondary_market_post_money_valuation_usd
# secondary_market_participants
# crowd_equity_funded_at
# crowd_equity_raised_amount_usd
# crowd_equity_pre_money_valuation_usd
# crowd_equity_post_money_valuation_usd
# crowd_equity_participants
# ipo
# is_acquired
# is_closed
# age

# %%
print("Total companies: ", data.shape[0])
print("Total features: ", data.shape[1])
print("Share of acquired companies: ", data.is_acquired.mean())
# Out:
# Total companies:  196704
# Total features:  117
# Share of acquired companies:  0.0483721734179

# %% [markdown]
# <H3>Testing data assumption</H3>

# %% [markdown]
# Columns 'age' and 'category_code' seem as important features. Let's test this assumption.

# %% [markdown]
# <H4>Probability of company acquisition depending on age (splitting by five years)</H4>
# Also count of companies of each age is located below.

# %%
age_acquisition = pd.DataFrame({'age': data.age.apply(lambda x: x // (365 * 5))})
age_acquisition['is_acquired'] = data.is_acquired
fig, axs = plt.subplots(2, 1, figsize=(15,15))
sns.barplot(x='age', y='is_acquired', data=age_acquisition, ax=axs[0])
sns.countplot(x='age', data=age_acquisition[age_acquisition['age'].notnull()], ax=axs[1])

# %% [markdown]
# <H4>Probability of company acquisition depending on company category</H4>

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))
p1 = sns.barplot(x='category_code', y='is_acquired', data=data, ax=axs[0])
p2 = sns.countplot(x='category_code', data=data, ax=axs[1])
for plot in [p1, p2]:
    for item in plot.get_xticklabels():
        item.set_rotation(45)

# %%
data.groupby(by='category_code').is_acquired.mean().sort_values(ascending=False)
# Out:
# category_code
# semiconductor       0.221264
# security            0.112245
# biotech             0.103114
# enterprise          0.093729
# network_hosting     0.087049
# messaging           0.084175
# software            0.082195
# public_relations    0.078136
# hardware            0.068405
# web                 0.065932
# mobile              0.061435
# cleantech           0.059248
# advertising         0.052080
# games_video         0.046734
# manufacturing       0.044118
# analytics           0.039101
# news                0.036411
# search              0.032967
# ecommerce           0.031071
# finance             0.028860
# consulting          0.027556
# music               0.025818
# other               0.023488
# photo_video         0.022059
# travel              0.021368
# social              0.020611
# fashion             0.019538
# automotive          0.017182
# hospitality         0.016927
# real_estate         0.016878
# health              0.015901
# transportation      0.014315
# nanotech            0.014286
# design              0.014235
# medical             0.013877
# education           0.011375
# sports              0.007407
# nonprofit           0.005435
# legal               0.003953
# local               0.003822
# government          0.000000
# pets                0.000000
# Name: is_acquired, dtype: float64

# %% [markdown]
# <H3>Share of non-null data in each column</H3>

# %%
data.notnull().mean().sort_values(ascending=False)
# Out:
# is_closed                                    1.000000
# is_acquired                                  1.000000
# ipo                                          1.000000
# status                                       1.000000
# region                                       1.000000
# category_code                                0.626901
# age                                          0.464337
# country_code                                 0.447947
# city                                         0.427109
# state_code                                   0.259258
# seed_participants                            0.051499
# seed_funded_at                               0.051061
# unattributed_participants                    0.049475
# unattributed_funded_at                       0.049272
# acquired_at                                  0.048372
# unattributed_raised_amount_usd               0.042439
# seed_raised_amount_usd                       0.040645
# a_participants                               0.038098
# a_funded_at                                  0.037915
# a_raised_amount_usd                          0.034290
# b_participants                               0.023019
# b_funded_at                                  0.023009
# b_raised_amount_usd                          0.021891
# angel_participants                           0.014341
# angel_funded_at                              0.014006
# debt_round_participants                      0.013950
# debt_round_funded_at                         0.013924
# debt_round_raised_amount_usd                 0.013767
# partial_funded_at                            0.013726
# partial_participants                         0.013726
#                                                ...
# crowd_post_money_valuation_usd               0.000025
# post_ipo_debt_participants                   0.000025
# partial_post_money_valuation_usd             0.000015
# crowd_equity_raised_amount_usd               0.000015
# crowd_equity_funded_at                       0.000015
# crowd_equity_participants                    0.000015
# e_post_money_valuation_usd                   0.000015
# secondary_market_raised_amount_usd           0.000010
# f_post_money_valuation_usd                   0.000010
# c_pre_money_valuation_usd                    0.000010
# d_pre_money_valuation_usd                    0.000005
# unattributed_pre_money_valuation_usd         0.000005
# g_post_money_valuation_usd                   0.000000
# crowd_equity_post_money_valuation_usd        0.000000
# secondary_market_pre_money_valuation_usd     0.000000
# secondary_market_post_money_valuation_usd    0.000000
# g_pre_money_valuation_usd                    0.000000
# crowd_equity_pre_money_valuation_usd         0.000000
# crowd_pre_money_valuation_usd                0.000000
# convertible_pre_money_valuation_usd          0.000000
# partial_pre_money_valuation_usd              0.000000
# seed_pre_money_valuation_usd                 0.000000
# post_ipo_debt_pre_money_valuation_usd        0.000000
# post_ipo_equity_pre_money_valuation_usd      0.000000
# grant_pre_money_valuation_usd                0.000000
# private_equity_pre_money_valuation_usd       0.000000
# debt_round_pre_money_valuation_usd           0.000000
# f_pre_money_valuation_usd                    0.000000
# e_pre_money_valuation_usd                    0.000000
# post_ipo_debt_post_money_valuation_usd       0.000000
# Length: 117, dtype: float64

# %% [markdown]
# As we can see there is a big number of columns which have small fullness. Those columns which have 100% fullness are categorical, so there is no possibility to extract usefull information directly from them. I suggest to create new features based on existing. For example, was_{round} = true if company was funded at {round}. Or there may be another approach for it: we can use {round}_participants and set {round}_participants = 0 if company was not funded at {round}.

# %% [markdown]
# <H3>Data correlation</H3>

# %% [markdown]
# But let's look at the correlation between numeric columns:

# %%
corrmat = data[data.dtypes[data.dtypes == np.float64].index].corr()
corrmat
# Out:
#                                            valuation_amount  raised_amount  \
# valuation_amount                                   1.000000       0.994552
# raised_amount                                      0.994552       1.000000
# b_raised_amount_usd                                0.034215       0.010206
# b_pre_money_valuation_usd                               NaN            NaN
# b_post_money_valuation_usd                              NaN            NaN
# b_participants                                     0.226182       0.153801
# angel_raised_amount_usd                           -1.000000            NaN
# angel_pre_money_valuation_usd                           NaN            NaN
# angel_post_money_valuation_usd                          NaN            NaN
# angel_participants                                      NaN       1.000000
# a_raised_amount_usd                               -0.072696      -0.035873
# a_pre_money_valuation_usd                          1.000000       1.000000
# a_post_money_valuation_usd                              NaN            NaN
# a_participants                                     0.116787       0.109288
# seed_raised_amount_usd                                  NaN      -0.247086
# seed_pre_money_valuation_usd                            NaN            NaN
# seed_post_money_valuation_usd                           NaN            NaN
# seed_participants                                       NaN      -0.148504
# c_raised_amount_usd                                0.233915       0.368141
# c_pre_money_valuation_usd                               NaN            NaN
# c_post_money_valuation_usd                              NaN            NaN
# c_participants                                    -0.110224      -0.038664
# d_raised_amount_usd                                0.236130       0.811103
# d_pre_money_valuation_usd                               NaN            NaN
# d_post_money_valuation_usd                              NaN            NaN
# d_participants                                    -0.123614      -0.194833
# unattributed_raised_amount_usd                     0.632402       0.986356
# unattributed_pre_money_valuation_usd                    NaN            NaN
# unattributed_post_money_valuation_usd                   NaN            NaN
# unattributed_participants                         -0.039141       0.003680
# ...                                                     ...            ...
# post_ipo_equity_participants                            NaN       0.950304
# post_ipo_debt_raised_amount_usd                         NaN            NaN
# post_ipo_debt_pre_money_valuation_usd                   NaN            NaN
# post_ipo_debt_post_money_valuation_usd                  NaN            NaN
# post_ipo_debt_participants                              NaN            NaN
# partial_raised_amount_usd                               NaN       0.797854
# partial_pre_money_valuation_usd                         NaN            NaN
# partial_post_money_valuation_usd                        NaN            NaN
# partial_participants                                    NaN            NaN
# convertible_raised_amount_usd                           NaN       1.000000
# convertible_pre_money_valuation_usd                     NaN            NaN
# convertible_post_money_valuation_usd                    NaN            NaN
# convertible_participants                                NaN            NaN
# crowd_raised_amount_usd                                 NaN            NaN
# crowd_pre_money_valuation_usd                           NaN            NaN
# crowd_post_money_valuation_usd                          NaN            NaN
# crowd_participants                                      NaN            NaN
# g_raised_amount_usd                                     NaN       1.000000
# g_pre_money_valuation_usd                               NaN            NaN
# g_post_money_valuation_usd                              NaN            NaN
# g_participants                                          NaN       1.000000
# secondary_market_raised_amount_usd                      NaN            NaN
# secondary_market_pre_money_valuation_usd                NaN            NaN
# secondary_market_post_money_valuation_usd               NaN            NaN
# secondary_market_participants                           NaN            NaN
# crowd_equity_raised_amount_usd                          NaN            NaN
# crowd_equity_pre_money_valuation_usd                    NaN            NaN
# crowd_equity_post_money_valuation_usd                   NaN            NaN
# crowd_equity_participants                               NaN            NaN
# age                                               -0.053796       0.384865
#
#                                            b_raised_amount_usd  \
# valuation_amount                                      0.034215
# raised_amount                                         0.010206
# b_raised_amount_usd                                   1.000000
# b_pre_money_valuation_usd                             0.872853
# b_post_money_valuation_usd                            0.582704
# b_participants                                        0.241413
# angel_raised_amount_usd                               0.457808
# angel_pre_money_valuation_usd                         1.000000
# angel_post_money_valuation_usd                        0.402629
# angel_participants                                    0.299071
# a_raised_amount_usd                                   0.534935
# a_pre_money_valuation_usd                             0.686418
# a_post_money_valuation_usd                            0.497150
# a_participants                                        0.099636
# seed_raised_amount_usd                                0.103413
# seed_pre_money_valuation_usd                               NaN
# seed_post_money_valuation_usd                         0.951600
# seed_participants                                     0.035185
# c_raised_amount_usd                                   0.434466
# c_pre_money_valuation_usd                             1.000000
# c_post_money_valuation_usd                            0.878970
# c_participants                                        0.181087
# d_raised_amount_usd                                   0.277326
# d_pre_money_valuation_usd                                  NaN
# d_post_money_valuation_usd                            0.986109
# d_participants                                       -0.001073
# unattributed_raised_amount_usd                        0.073081
# unattributed_pre_money_valuation_usd                       NaN
# unattributed_post_money_valuation_usd                -0.421520
# unattributed_participants                            -0.013394
# ...                                                        ...
# post_ipo_equity_participants                               NaN
# post_ipo_debt_raised_amount_usd                            NaN
# post_ipo_debt_pre_money_valuation_usd                      NaN
# post_ipo_debt_post_money_valuation_usd                     NaN
# post_ipo_debt_participants                                 NaN
# partial_raised_amount_usd                             0.327080
# partial_pre_money_valuation_usd                            NaN
# partial_post_money_valuation_usd                           NaN
# partial_participants                                  0.233564
# convertible_raised_amount_usd                         0.560898
# convertible_pre_money_valuation_usd                        NaN
# convertible_post_money_valuation_usd                       NaN
# convertible_participants                             -0.096611
# crowd_raised_amount_usd                                    NaN
# crowd_pre_money_valuation_usd                              NaN
# crowd_post_money_valuation_usd                             NaN
# crowd_participants                                         NaN
# g_raised_amount_usd                                   0.426536
# g_pre_money_valuation_usd                                  NaN
# g_post_money_valuation_usd                                 NaN
# g_participants                                        0.360946
# secondary_market_raised_amount_usd                    1.000000
# secondary_market_pre_money_valuation_usd                   NaN
# secondary_market_post_money_valuation_usd                  NaN
# secondary_market_participants                        -0.114673
# crowd_equity_raised_amount_usd                             NaN
# crowd_equity_pre_money_valuation_usd                       NaN
# crowd_equity_post_money_valuation_usd                      NaN
# crowd_equity_participants                                  NaN
# age                                                   0.029238
#
#                                            b_pre_money_valuation_usd  \
# valuation_amount                                                 NaN
# raised_amount                                                    NaN
# b_raised_amount_usd                                         0.872853
# b_pre_money_valuation_usd                                   1.000000
# b_post_money_valuation_usd                                  0.996246
# b_participants                                             -0.026134
# angel_raised_amount_usd                                    -0.639824
# angel_pre_money_valuation_usd                                    NaN
# angel_post_money_valuation_usd                                   NaN
# angel_participants                                         -0.151327
# a_raised_amount_usd                                         0.847082
# a_pre_money_valuation_usd                                   1.000000
# a_post_money_valuation_usd                                       NaN
# a_participants                                              0.268961
# seed_raised_amount_usd                                           NaN
# seed_pre_money_valuation_usd                                     NaN
# seed_post_money_valuation_usd                                    NaN
# seed_participants                                                NaN
# c_raised_amount_usd                                         1.000000
# c_pre_money_valuation_usd                                        NaN
# c_post_money_valuation_usd                                       NaN
# c_participants                                                   NaN
# d_raised_amount_usd                                              NaN
# d_pre_money_valuation_usd                                        NaN
# d_post_money_valuation_usd                                       NaN
# d_participants                                                   NaN
# unattributed_raised_amount_usd                                   NaN
# unattributed_pre_money_valuation_usd                             NaN
# unattributed_post_money_valuation_usd                            NaN
# unattributed_participants                                        NaN
# ...                                                              ...
# post_ipo_equity_participants                                     NaN
# post_ipo_debt_raised_amount_usd                                  NaN
# post_ipo_debt_pre_money_valuation_usd                            NaN
# post_ipo_debt_post_money_valuation_usd                           NaN
# post_ipo_debt_participants                                       NaN
# partial_raised_amount_usd                                        NaN
# partial_pre_money_valuation_usd                                  NaN
# partial_post_money_valuation_usd                                 NaN
# partial_participants                                             NaN
# convertible_raised_amount_usd                                    NaN
# convertible_pre_money_valuation_usd                              NaN
# convertible_post_money_valuation_usd                             NaN
# convertible_participants                                         NaN
# crowd_raised_amount_usd                                          NaN
# crowd_pre_money_valuation_usd                                    NaN
# crowd_post_money_valuation_usd                                   NaN
# crowd_participants                                               NaN
# g_raised_amount_usd                                              NaN
# g_pre_money_valuation_usd                                        NaN
# g_post_money_valuation_usd                                       NaN
# g_participants                                                   NaN
# secondary_market_raised_amount_usd                               NaN
# secondary_market_pre_money_valuation_usd                         NaN
# secondary_market_post_money_valuation_usd                        NaN
# secondary_market_participants                                    NaN
# crowd_equity_raised_amount_usd                                   NaN
# crowd_equity_pre_money_valuation_usd                             NaN
# crowd_equity_post_money_valuation_usd                            NaN
# crowd_equity_participants                                        NaN
# age                                                         0.075100
#
#                                            b_post_money_valuation_usd  \
# valuation_amount                                                  NaN
# raised_amount                                                     NaN
# b_raised_amount_usd                                          0.582704
# b_pre_money_valuation_usd                                    0.996246
# b_post_money_valuation_usd                                   1.000000
# b_participants                                               0.462632
# angel_raised_amount_usd                                      0.664186
# angel_pre_money_valuation_usd                                     NaN
# angel_post_money_valuation_usd                                    NaN
# angel_participants                                           0.630952
# a_raised_amount_usd                                          0.658877
# a_pre_money_valuation_usd                                         NaN
# a_post_money_valuation_usd                                   0.498347
# a_participants                                               0.350366
# seed_raised_amount_usd                                       0.918020
# seed_pre_money_valuation_usd                                      NaN
# seed_post_money_valuation_usd                                     NaN
# seed_participants                                            0.531947
# c_raised_amount_usd                                          0.953102
# c_pre_money_valuation_usd                                         NaN
# c_post_money_valuation_usd                                   1.000000
# c_participants                                              -0.431593
# d_raised_amount_usd                                          0.860720
# d_pre_money_valuation_usd                                         NaN
# d_post_money_valuation_usd                                   1.000000
# d_participants                                                    NaN
# unattributed_raised_amount_usd                              -1.000000
# unattributed_pre_money_valuation_usd                              NaN
# unattributed_post_money_valuation_usd                             NaN
# unattributed_participants                                   -1.000000
# ...                                                               ...
# post_ipo_equity_participants                                      NaN
# post_ipo_debt_raised_amount_usd                                   NaN
# post_ipo_debt_pre_money_valuation_usd                             NaN
# post_ipo_debt_post_money_valuation_usd                            NaN
# post_ipo_debt_participants                                        NaN
# partial_raised_amount_usd                                         NaN
# partial_pre_money_valuation_usd                                   NaN
# partial_post_money_valuation_usd                                  NaN
# partial_participants                                              NaN
# convertible_raised_amount_usd                                     NaN
# convertible_pre_money_valuation_usd                               NaN
# convertible_post_money_valuation_usd                              NaN
# convertible_participants                                          NaN
# crowd_raised_amount_usd                                           NaN
# crowd_pre_money_valuation_usd                                     NaN
# crowd_post_money_valuation_usd                                    NaN
# crowd_participants                                                NaN
# g_raised_amount_usd                                               NaN
# g_pre_money_valuation_usd                                         NaN
# g_post_money_valuation_usd                                        NaN
# g_participants                                                    NaN
# secondary_market_raised_amount_usd                                NaN
# secondary_market_pre_money_valuation_usd                          NaN
# secondary_market_post_money_valuation_usd                         NaN
# secondary_market_participants                                     NaN
# crowd_equity_raised_amount_usd                                    NaN
# crowd_equity_pre_money_valuation_usd                              NaN
# crowd_equity_post_money_valuation_usd                             NaN
# crowd_equity_participants                                         NaN
# age                                                          0.156818
#
#                                            b_participants  \
# valuation_amount                                 0.226182
# raised_amount                                    0.153801
# b_raised_amount_usd                              0.241413
# b_pre_money_valuation_usd                       -0.026134
# b_post_money_valuation_usd                       0.462632
# b_participants                                   1.000000
# angel_raised_amount_usd                          0.146946
# angel_pre_money_valuation_usd                         NaN
# angel_post_money_valuation_usd                   0.631044
# angel_participants                               0.398152
# a_raised_amount_usd                              0.036055
# a_pre_money_valuation_usd                       -0.012820
# a_post_money_valuation_usd                       0.260836
# a_participants                                   0.405003
# seed_raised_amount_usd                           0.010681
# seed_pre_money_valuation_usd                          NaN
# seed_post_money_valuation_usd                    0.321856
# seed_participants                                0.253460
# c_raised_amount_usd                              0.077779
# c_pre_money_valuation_usd                       -1.000000
# c_post_money_valuation_usd                       0.030079
# c_participants                                   0.437025
# d_raised_amount_usd                              0.007648
# d_pre_money_valuation_usd                             NaN
# d_post_money_valuation_usd                      -0.516442
# d_participants                                   0.137183
# unattributed_raised_amount_usd                   0.027409
# unattributed_pre_money_valuation_usd                  NaN
# unattributed_post_money_valuation_usd            0.588517
# unattributed_participants                        0.136477
# ...                                                   ...
# post_ipo_equity_participants                          NaN
# post_ipo_debt_raised_amount_usd                       NaN
# post_ipo_debt_pre_money_valuation_usd                 NaN
# post_ipo_debt_post_money_valuation_usd                NaN
# post_ipo_debt_participants                            NaN
# partial_raised_amount_usd                        0.025974
# partial_pre_money_valuation_usd                       NaN
# partial_post_money_valuation_usd                      NaN
# partial_participants                             0.126838
# convertible_raised_amount_usd                    0.054743
# convertible_pre_money_valuation_usd                   NaN
# convertible_post_money_valuation_usd                  NaN
# convertible_participants                        -0.164219
# crowd_raised_amount_usd                               NaN
# crowd_pre_money_valuation_usd                         NaN
# crowd_post_money_valuation_usd                        NaN
# crowd_participants                                    NaN
# g_raised_amount_usd                              0.632493
# g_pre_money_valuation_usd                             NaN
# g_post_money_valuation_usd                            NaN
# g_participants                                   0.670874
# secondary_market_raised_amount_usd               1.000000
# secondary_market_pre_money_valuation_usd              NaN
# secondary_market_post_money_valuation_usd             NaN
# secondary_market_participants                   -0.294102
# crowd_equity_raised_amount_usd                        NaN
# crowd_equity_pre_money_valuation_usd                  NaN
# crowd_equity_post_money_valuation_usd                 NaN
# crowd_equity_participants                             NaN
# age                                              0.000355
#
#                                            angel_raised_amount_usd  \
# valuation_amount                                         -1.000000
# raised_amount                                                  NaN
# b_raised_amount_usd                                       0.457808
# b_pre_money_valuation_usd                                -0.639824
# b_post_money_valuation_usd                                0.664186
# b_participants                                            0.146946
# angel_raised_amount_usd                                   1.000000
# angel_pre_money_valuation_usd                             0.472915
# angel_post_money_valuation_usd                            0.204218
# angel_participants                                        0.080525
# a_raised_amount_usd                                       0.384970
# a_pre_money_valuation_usd                                -1.000000
# a_post_money_valuation_usd                                0.516698
# a_participants                                           -0.037341
# seed_raised_amount_usd                                    0.404890
# seed_pre_money_valuation_usd                                   NaN
# seed_post_money_valuation_usd                             0.746339
# seed_participants                                         0.038478
# c_raised_amount_usd                                      -0.020894
# c_pre_money_valuation_usd                                      NaN
# c_post_money_valuation_usd                                0.578289
# c_participants                                           -0.168597
# d_raised_amount_usd                                       0.020491
# d_pre_money_valuation_usd                                      NaN
# d_post_money_valuation_usd                                1.000000
# d_participants                                            0.104725
# unattributed_raised_amount_usd                           -0.019157
# unattributed_pre_money_valuation_usd                           NaN
# unattributed_post_money_valuation_usd                     0.998331
# unattributed_participants                                -0.083738
# ...                                                            ...
# post_ipo_equity_participants                                   NaN
# post_ipo_debt_raised_amount_usd                                NaN
# post_ipo_debt_pre_money_valuation_usd                          NaN
# post_ipo_debt_post_money_valuation_usd                         NaN
# post_ipo_debt_participants                                     NaN
# partial_raised_amount_usd                                 0.220466
# partial_pre_money_valuation_usd                                NaN
# partial_post_money_valuation_usd                               NaN
# partial_participants                                           NaN
# convertible_raised_amount_usd                             0.897882
# convertible_pre_money_valuation_usd                            NaN
# convertible_post_money_valuation_usd                           NaN
# convertible_participants                                 -0.496162
# crowd_raised_amount_usd                                   0.487627
# crowd_pre_money_valuation_usd                                  NaN
# crowd_post_money_valuation_usd                                 NaN
# crowd_participants                                             NaN
# g_raised_amount_usd                                            NaN
# g_pre_money_valuation_usd                                      NaN
# g_post_money_valuation_usd                                     NaN
# g_participants                                                 NaN
# secondary_market_raised_amount_usd                             NaN
# secondary_market_pre_money_valuation_usd                       NaN
# secondary_market_post_money_valuation_usd                      NaN
# secondary_market_participants                                  NaN
# crowd_equity_raised_amount_usd                                 NaN
# crowd_equity_pre_money_valuation_usd                           NaN
# crowd_equity_post_money_valuation_usd                          NaN
# crowd_equity_participants                                      NaN
# age                                                       0.201118
#
#                                            angel_pre_money_valuation_usd  \
# valuation_amount                                                     NaN
# raised_amount                                                        NaN
# b_raised_amount_usd                                             1.000000
# b_pre_money_valuation_usd                                            NaN
# b_post_money_valuation_usd                                           NaN
# b_participants                                                       NaN
# angel_raised_amount_usd                                         0.472915
# angel_pre_money_valuation_usd                                   1.000000
# angel_post_money_valuation_usd                                 -0.261826
# angel_participants                                              0.481077
# a_raised_amount_usd                                                  NaN
# a_pre_money_valuation_usd                                            NaN
# a_post_money_valuation_usd                                           NaN
# a_participants                                                       NaN
# seed_raised_amount_usd                                               NaN
# seed_pre_money_valuation_usd                                         NaN
# seed_post_money_valuation_usd                                        NaN
# seed_participants                                                    NaN
# c_raised_amount_usd                                                  NaN
# c_pre_money_valuation_usd                                            NaN
# c_post_money_valuation_usd                                           NaN
# c_participants                                                       NaN
# d_raised_amount_usd                                                  NaN
# d_pre_money_valuation_usd                                            NaN
# d_post_money_valuation_usd                                           NaN
# d_participants                                                       NaN
# unattributed_raised_amount_usd                                       NaN
# unattributed_pre_money_valuation_usd                                 NaN
# unattributed_post_money_valuation_usd                                NaN
# unattributed_participants                                            NaN
# ...                                                                  ...
# post_ipo_equity_participants                                         NaN
# post_ipo_debt_raised_amount_usd                                      NaN
# post_ipo_debt_pre_money_valuation_usd                                NaN
# post_ipo_debt_post_money_valuation_usd                               NaN
# post_ipo_debt_participants                                           NaN
# partial_raised_amount_usd                                            NaN
# partial_pre_money_valuation_usd                                      NaN
# partial_post_money_valuation_usd                                     NaN
# partial_participants                                                 NaN
# convertible_raised_amount_usd                                        NaN
# convertible_pre_money_valuation_usd                                  NaN
# convertible_post_money_valuation_usd                                 NaN
# convertible_participants                                             NaN
# crowd_raised_amount_usd                                              NaN
# crowd_pre_money_valuation_usd                                        NaN
# crowd_post_money_valuation_usd                                       NaN
# crowd_participants                                                   NaN
# g_raised_amount_usd                                                  NaN
# g_pre_money_valuation_usd                                            NaN
# g_post_money_valuation_usd                                           NaN
# g_participants                                                       NaN
# secondary_market_raised_amount_usd                                   NaN
# secondary_market_pre_money_valuation_usd                             NaN
# secondary_market_post_money_valuation_usd                            NaN
# secondary_market_participants                                        NaN
# crowd_equity_raised_amount_usd                                       NaN
# crowd_equity_pre_money_valuation_usd                                 NaN
# crowd_equity_post_money_valuation_usd                                NaN
# crowd_equity_participants                                            NaN
# age                                                             0.551160
#
#                                            angel_post_money_valuation_usd  \
# valuation_amount                                                      NaN
# raised_amount                                                         NaN
# b_raised_amount_usd                                              0.402629
# b_pre_money_valuation_usd                                             NaN
# b_post_money_valuation_usd                                            NaN
# b_participants                                                   0.631044
# angel_raised_amount_usd                                          0.204218
# angel_pre_money_valuation_usd                                   -0.261826
# angel_post_money_valuation_usd                                   1.000000
# angel_participants                                              -0.042225
# a_raised_amount_usd                                              0.740116
# a_pre_money_valuation_usd                                             NaN
# a_post_money_valuation_usd                                       0.904194
# a_participants                                                   0.333111
# seed_raised_amount_usd                                           0.261601
# seed_pre_money_valuation_usd                                          NaN
# seed_post_money_valuation_usd                                    0.866895
# seed_participants                                               -0.140840
# c_raised_amount_usd                                              1.000000
# c_pre_money_valuation_usd                                             NaN
# c_post_money_valuation_usd                                            NaN
# c_participants                                                  -1.000000
# d_raised_amount_usd                                                   NaN
# d_pre_money_valuation_usd                                             NaN
# d_post_money_valuation_usd                                            NaN
# d_participants                                                        NaN
# unattributed_raised_amount_usd                                   0.999930
# unattributed_pre_money_valuation_usd                                  NaN
# unattributed_post_money_valuation_usd                                 NaN
# unattributed_participants                                             NaN
# ...                                                                   ...
# post_ipo_equity_participants                                          NaN
# post_ipo_debt_raised_amount_usd                                       NaN
# post_ipo_debt_pre_money_valuation_usd                                 NaN
# post_ipo_debt_post_money_valuation_usd                                NaN
# post_ipo_debt_participants                                            NaN
# partial_raised_amount_usd                                        1.000000
# partial_pre_money_valuation_usd                                       NaN
# partial_post_money_valuation_usd                                      NaN
# partial_participants                                                  NaN
# convertible_raised_amount_usd                                         NaN
# convertible_pre_money_valuation_usd                                   NaN
# convertible_post_money_valuation_usd                                  NaN
# convertible_participants                                              NaN
# crowd_raised_amount_usd                                               NaN
# crowd_pre_money_valuation_usd                                         NaN
# crowd_post_money_valuation_usd                                        NaN
# crowd_participants                                                    NaN
# g_raised_amount_usd                                                   NaN
# g_pre_money_valuation_usd                                             NaN
# g_post_money_valuation_usd                                            NaN
# g_participants                                                        NaN
# secondary_market_raised_amount_usd                                    NaN
# secondary_market_pre_money_valuation_usd                              NaN
# secondary_market_post_money_valuation_usd                             NaN
# secondary_market_participants                                         NaN
# crowd_equity_raised_amount_usd                                        NaN
# crowd_equity_pre_money_valuation_usd                                  NaN
# crowd_equity_post_money_valuation_usd                                 NaN
# crowd_equity_participants                                             NaN
# age                                                              0.187893
#
#                                            angel_participants    ...     \
# valuation_amount                                          NaN    ...
# raised_amount                                        1.000000    ...
# b_raised_amount_usd                                  0.299071    ...
# b_pre_money_valuation_usd                           -0.151327    ...
# b_post_money_valuation_usd                           0.630952    ...
# b_participants                                       0.398152    ...
# angel_raised_amount_usd                              0.080525    ...
# angel_pre_money_valuation_usd                        0.481077    ...
# angel_post_money_valuation_usd                      -0.042225    ...
# angel_participants                                   1.000000    ...
# a_raised_amount_usd                                  0.182941    ...
# a_pre_money_valuation_usd                           -0.140028    ...
# a_post_money_valuation_usd                          -0.250923    ...
# a_participants                                       0.371777    ...
# seed_raised_amount_usd                               0.076411    ...
# seed_pre_money_valuation_usd                              NaN    ...
# seed_post_money_valuation_usd                       -0.181694    ...
# seed_participants                                    0.251734    ...
# c_raised_amount_usd                                  0.200344    ...
# c_pre_money_valuation_usd                                 NaN    ...
# c_post_money_valuation_usd                           0.902389    ...
# c_participants                                       0.170693    ...
# d_raised_amount_usd                                  0.103974    ...
# d_pre_money_valuation_usd                                 NaN    ...
# d_post_money_valuation_usd                           1.000000    ...
# d_participants                                       0.171548    ...
# unattributed_raised_amount_usd                       0.011149    ...
# unattributed_pre_money_valuation_usd                      NaN    ...
# unattributed_post_money_valuation_usd                0.505703    ...
# unattributed_participants                            0.235890    ...
# ...                                                       ...    ...
# post_ipo_equity_participants                              NaN    ...
# post_ipo_debt_raised_amount_usd                           NaN    ...
# post_ipo_debt_pre_money_valuation_usd                     NaN    ...
# post_ipo_debt_post_money_valuation_usd                    NaN    ...
# post_ipo_debt_participants                                NaN    ...
# partial_raised_amount_usd                            0.033715    ...
# partial_pre_money_valuation_usd                           NaN    ...
# partial_post_money_valuation_usd                          NaN    ...
# partial_participants                                      NaN    ...
# convertible_raised_amount_usd                        0.780241    ...
# convertible_pre_money_valuation_usd                       NaN    ...
# convertible_post_money_valuation_usd                      NaN    ...
# convertible_participants                            -0.510061    ...
# crowd_raised_amount_usd                              0.754854    ...
# crowd_pre_money_valuation_usd                             NaN    ...
# crowd_post_money_valuation_usd                            NaN    ...
# crowd_participants                                   0.254824    ...
# g_raised_amount_usd                                       NaN    ...
# g_pre_money_valuation_usd                                 NaN    ...
# g_post_money_valuation_usd                                NaN    ...
# g_participants                                            NaN    ...
# secondary_market_raised_amount_usd                        NaN    ...
# secondary_market_pre_money_valuation_usd                  NaN    ...
# secondary_market_post_money_valuation_usd                 NaN    ...
# secondary_market_participants                             NaN    ...
# crowd_equity_raised_amount_usd                            NaN    ...
# crowd_equity_pre_money_valuation_usd                      NaN    ...
# crowd_equity_post_money_valuation_usd                     NaN    ...
# crowd_equity_participants                                 NaN    ...
# age                                                 -0.054726    ...
#
#                                            g_participants  \
# valuation_amount                                      NaN
# raised_amount                                    1.000000
# b_raised_amount_usd                              0.360946
# b_pre_money_valuation_usd                             NaN
# b_post_money_valuation_usd                            NaN
# b_participants                                   0.670874
# angel_raised_amount_usd                               NaN
# angel_pre_money_valuation_usd                         NaN
# angel_post_money_valuation_usd                        NaN
# angel_participants                                    NaN
# a_raised_amount_usd                              0.945816
# a_pre_money_valuation_usd                             NaN
# a_post_money_valuation_usd                            NaN
# a_participants                                   0.823399
# seed_raised_amount_usd                                NaN
# seed_pre_money_valuation_usd                          NaN
# seed_post_money_valuation_usd                         NaN
# seed_participants                                     NaN
# c_raised_amount_usd                              0.499425
# c_pre_money_valuation_usd                             NaN
# c_post_money_valuation_usd                            NaN
# c_participants                                  -0.034818
# d_raised_amount_usd                              0.703050
# d_pre_money_valuation_usd                             NaN
# d_post_money_valuation_usd                            NaN
# d_participants                                  -0.530205
# unattributed_raised_amount_usd                  -0.164912
# unattributed_pre_money_valuation_usd                  NaN
# unattributed_post_money_valuation_usd                 NaN
# unattributed_participants                       -0.041115
# ...                                                   ...
# post_ipo_equity_participants                          NaN
# post_ipo_debt_raised_amount_usd                       NaN
# post_ipo_debt_pre_money_valuation_usd                 NaN
# post_ipo_debt_post_money_valuation_usd                NaN
# post_ipo_debt_participants                            NaN
# partial_raised_amount_usd                             NaN
# partial_pre_money_valuation_usd                       NaN
# partial_post_money_valuation_usd                      NaN
# partial_participants                                  NaN
# convertible_raised_amount_usd                         NaN
# convertible_pre_money_valuation_usd                   NaN
# convertible_post_money_valuation_usd                  NaN
# convertible_participants                              NaN
# crowd_raised_amount_usd                               NaN
# crowd_pre_money_valuation_usd                         NaN
# crowd_post_money_valuation_usd                        NaN
# crowd_participants                                    NaN
# g_raised_amount_usd                              0.283178
# g_pre_money_valuation_usd                             NaN
# g_post_money_valuation_usd                            NaN
# g_participants                                   1.000000
# secondary_market_raised_amount_usd                    NaN
# secondary_market_pre_money_valuation_usd              NaN
# secondary_market_post_money_valuation_usd             NaN
# secondary_market_participants                         NaN
# crowd_equity_raised_amount_usd                        NaN
# crowd_equity_pre_money_valuation_usd                  NaN
# crowd_equity_post_money_valuation_usd                 NaN
# crowd_equity_participants                             NaN
# age                                             -0.205936
#
#                                            secondary_market_raised_amount_usd  \
# valuation_amount                                                          NaN
# raised_amount                                                             NaN
# b_raised_amount_usd                                                       1.0
# b_pre_money_valuation_usd                                                 NaN
# b_post_money_valuation_usd                                                NaN
# b_participants                                                            1.0
# angel_raised_amount_usd                                                   NaN
# angel_pre_money_valuation_usd                                             NaN
# angel_post_money_valuation_usd                                            NaN
# angel_participants                                                        NaN
# a_raised_amount_usd                                                      -1.0
# a_pre_money_valuation_usd                                                 NaN
# a_post_money_valuation_usd                                                NaN
# a_participants                                                            1.0
# seed_raised_amount_usd                                                    NaN
# seed_pre_money_valuation_usd                                              NaN
# seed_post_money_valuation_usd                                             NaN
# seed_participants                                                         NaN
# c_raised_amount_usd                                                       1.0
# c_pre_money_valuation_usd                                                 NaN
# c_post_money_valuation_usd                                                NaN
# c_participants                                                            1.0
# d_raised_amount_usd                                                       1.0
# d_pre_money_valuation_usd                                                 NaN
# d_post_money_valuation_usd                                                NaN
# d_participants                                                            1.0
# unattributed_raised_amount_usd                                            NaN
# unattributed_pre_money_valuation_usd                                      NaN
# unattributed_post_money_valuation_usd                                     NaN
# unattributed_participants                                                 NaN
# ...                                                                       ...
# post_ipo_equity_participants                                              NaN
# post_ipo_debt_raised_amount_usd                                           NaN
# post_ipo_debt_pre_money_valuation_usd                                     NaN
# post_ipo_debt_post_money_valuation_usd                                    NaN
# post_ipo_debt_participants                                                NaN
# partial_raised_amount_usd                                                 NaN
# partial_pre_money_valuation_usd                                           NaN
# partial_post_money_valuation_usd                                          NaN
# partial_participants                                                      NaN
# convertible_raised_amount_usd                                             NaN
# convertible_pre_money_valuation_usd                                       NaN
# convertible_post_money_valuation_usd                                      NaN
# convertible_participants                                                  NaN
# crowd_raised_amount_usd                                                   NaN
# crowd_pre_money_valuation_usd                                             NaN
# crowd_post_money_valuation_usd                                            NaN
# crowd_participants                                                        NaN
# ...
# secondary_market_post_money_valuation_usd                             NaN
# secondary_market_participants                                         NaN
# crowd_equity_raised_amount_usd                                        1.0
# crowd_equity_pre_money_valuation_usd                                  NaN
# crowd_equity_post_money_valuation_usd                                 NaN
# crowd_equity_participants                                             NaN
# age                                                                   1.0
#
#                                            crowd_equity_pre_money_valuation_usd  \
# valuation_amount                                                            NaN
# raised_amount                                                               NaN
# b_raised_amount_usd                                                         NaN
# b_pre_money_valuation_usd                                                   NaN
# b_post_money_valuation_usd                                                  NaN
# b_participants                                                              NaN
# angel_raised_amount_usd                                                     NaN
# angel_pre_money_valuation_usd                                               NaN
# angel_post_money_valuation_usd                                              NaN
# angel_participants                                                          NaN
# a_raised_amount_usd                                                         NaN
# a_pre_money_valuation_usd                                                   NaN
# a_post_money_valuation_usd                                                  NaN
# a_participants                                                              NaN
# seed_raised_amount_usd                                                      NaN
# seed_pre_money_valuation_usd                                                NaN
# seed_post_money_valuation_usd                                               NaN
# seed_participants                                                           NaN
# c_raised_amount_usd                                                         NaN
# c_pre_money_valuation_usd                                                   NaN
# c_post_money_valuation_usd                                                  NaN
# c_participants                                                              NaN
# d_raised_amount_usd                                                         NaN
# d_pre_money_valuation_usd                                                   NaN
# d_post_money_valuation_usd                                                  NaN
# d_participants                                                              NaN
# unattributed_raised_amount_usd                                              NaN
# unattributed_pre_money_valuation_usd                                        NaN
# unattributed_post_money_valuation_usd                                       NaN
# unattributed_participants                                                   NaN
# ...                                                                         ...
# post_ipo_equity_participants                                                NaN
# post_ipo_debt_raised_amount_usd                                             NaN
# post_ipo_debt_pre_money_valuation_usd                                       NaN
# post_ipo_debt_post_money_valuation_usd                                      NaN
# post_ipo_debt_participants                                                  NaN
# partial_raised_amount_usd                                                   NaN
# partial_pre_money_valuation_usd                                             NaN
# partial_post_money_valuation_usd                                            NaN
# partial_participants                                                        NaN
# convertible_raised_amount_usd                                               NaN
# convertible_pre_money_valuation_usd                                         NaN
# convertible_post_money_valuation_usd                                        NaN
# convertible_participants                                                    NaN
# crowd_raised_amount_usd                                                     NaN
# crowd_pre_money_valuation_usd                                               NaN
# crowd_post_money_valuation_usd                                              NaN
# crowd_participants                                                          NaN
# g_raised_amount_usd                                                         NaN
# g_pre_money_valuation_usd                                                   NaN
# g_post_money_valuation_usd                                                  NaN
# g_participants                                                              NaN
# secondary_market_raised_amount_usd                                          NaN
# secondary_market_pre_money_valuation_usd                                    NaN
# secondary_market_post_money_valuation_usd                                   NaN
# secondary_market_participants                                               NaN
# crowd_equity_raised_amount_usd                                              NaN
# crowd_equity_pre_money_valuation_usd                                        NaN
# crowd_equity_post_money_valuation_usd                                       NaN
# crowd_equity_participants                                                   NaN
# age                                                                         NaN
#
#                                            crowd_equity_post_money_valuation_usd  \
# valuation_amount                                                             NaN
# raised_amount                                                                NaN
# b_raised_amount_usd                                                          NaN
# b_pre_money_valuation_usd                                                    NaN
# b_post_money_valuation_usd                                                   NaN
# b_participants                                                               NaN
# angel_raised_amount_usd                                                      NaN
# angel_pre_money_valuation_usd                                                NaN
# angel_post_money_valuation_usd                                               NaN
# angel_participants                                                           NaN
# a_raised_amount_usd                                                          NaN
# a_pre_money_valuation_usd                                                    NaN
# a_post_money_valuation_usd                                                   NaN
# a_participants                                                               NaN
# seed_raised_amount_usd                                                       NaN
# seed_pre_money_valuation_usd                                                 NaN
# seed_post_money_valuation_usd                                                NaN
# seed_participants                                                            NaN
# c_raised_amount_usd                                                          NaN
# c_pre_money_valuation_usd                                                    NaN
# c_post_money_valuation_usd                                                   NaN
# c_participants                                                               NaN
# d_raised_amount_usd                                                          NaN
# d_pre_money_valuation_usd                                                    NaN
# d_post_money_valuation_usd                                                   NaN
# d_participants                                                               NaN
# unattributed_raised_amount_usd                                               NaN
# unattributed_pre_money_valuation_usd                                         NaN
# unattributed_post_money_valuation_usd                                        NaN
# unattributed_participants                                                    NaN
# ...                                                                          ...
# post_ipo_equity_participants                                                 NaN
# post_ipo_debt_raised_amount_usd                                              NaN
# post_ipo_debt_pre_money_valuation_usd                                        NaN
# post_ipo_debt_post_money_valuation_usd                                       NaN
# post_ipo_debt_participants                                                   NaN
# partial_raised_amount_usd                                                    NaN
# partial_pre_money_valuation_usd                                              NaN
# partial_post_money_valuation_usd                                             NaN
# partial_participants                                                         NaN
# convertible_raised_amount_usd                                                NaN
# convertible_pre_money_valuation_usd                                          NaN
# convertible_post_money_valuation_usd                                         NaN
# convertible_participants                                                     NaN
# crowd_raised_amount_usd                                                      NaN
# crowd_pre_money_valuation_usd                                                NaN
# crowd_post_money_valuation_usd                                               NaN
# crowd_participants                                                           NaN
# g_raised_amount_usd                                                          NaN
# g_pre_money_valuation_usd                                                    NaN
# g_post_money_valuation_usd                                                   NaN
# g_participants                                                               NaN
# secondary_market_raised_amount_usd                                           NaN
# secondary_market_pre_money_valuation_usd                                     NaN
# secondary_market_post_money_valuation_usd                                    NaN
# secondary_market_participants                                                NaN
# crowd_equity_raised_amount_usd                                               NaN
# crowd_equity_pre_money_valuation_usd                                         NaN
# crowd_equity_post_money_valuation_usd                                        NaN
# crowd_equity_participants                                                    NaN
# age                                                                          NaN
#
#                                            crowd_equity_participants       age
# valuation_amount                                                 NaN -0.053796
# raised_amount                                                    NaN  0.384865
# b_raised_amount_usd                                              NaN  0.029238
# b_pre_money_valuation_usd                                        NaN  0.075100
# b_post_money_valuation_usd                                       NaN  0.156818
# b_participants                                                   NaN  0.000355
# angel_raised_amount_usd                                          NaN  0.201118
# angel_pre_money_valuation_usd                                    NaN  0.551160
# angel_post_money_valuation_usd                                   NaN  0.187893
# angel_participants                                               NaN -0.054726
# a_raised_amount_usd                                              NaN  0.160901
# a_pre_money_valuation_usd                                        NaN  0.272858
# a_post_money_valuation_usd                                       NaN  0.003076
# a_participants                                                   NaN -0.113422
# seed_raised_amount_usd                                           NaN  0.109590
# seed_pre_money_valuation_usd                                     NaN       NaN
# seed_post_money_valuation_usd                                    NaN  0.100623
# seed_participants                                                NaN -0.102442
# c_raised_amount_usd                                              NaN -0.061037
# c_pre_money_valuation_usd                                        NaN -1.000000
# c_post_money_valuation_usd                                       NaN -0.336625
# c_participants                                                   NaN  0.025846
# d_raised_amount_usd                                              NaN -0.080358
# d_pre_money_valuation_usd                                        NaN       NaN
# d_post_money_valuation_usd                                       NaN -0.428411
# d_participants                                                   NaN  0.025138
# unattributed_raised_amount_usd                                   NaN  0.144785
# unattributed_pre_money_valuation_usd                             NaN       NaN
# unattributed_post_money_valuation_usd                            NaN  0.348743
# unattributed_participants                                        NaN  0.007014
# ...                                                              ...       ...
# post_ipo_equity_participants                                     NaN -0.074719
# post_ipo_debt_raised_amount_usd                                  NaN -0.980015
# post_ipo_debt_pre_money_valuation_usd                            NaN       NaN
# post_ipo_debt_post_money_valuation_usd                           NaN       NaN
# post_ipo_debt_participants                                       NaN -0.914556
# partial_raised_amount_usd                                        NaN  0.167851
# partial_pre_money_valuation_usd                                  NaN       NaN
# partial_post_money_valuation_usd                                 NaN  0.027363
# partial_participants                                             NaN  0.012512
# convertible_raised_amount_usd                                    NaN  0.258526
# convertible_pre_money_valuation_usd                              NaN       NaN
# convertible_post_money_valuation_usd                             NaN  0.782969
# convertible_participants                                         NaN -0.182487
# crowd_raised_amount_usd                                          NaN  0.499879
# crowd_pre_money_valuation_usd                                    NaN       NaN
# crowd_post_money_valuation_usd                                   NaN  0.023266
# crowd_participants                                               NaN  0.054546
# g_raised_amount_usd                                              NaN -0.276554
# g_pre_money_valuation_usd                                        NaN       NaN
# g_post_money_valuation_usd                                       NaN       NaN
# g_participants                                                   NaN -0.205936
# secondary_market_raised_amount_usd                               NaN -1.000000
# secondary_market_pre_money_valuation_usd                         NaN       NaN
# secondary_market_post_money_valuation_usd                        NaN       NaN
# secondary_market_participants                                    NaN  0.114067
# crowd_equity_raised_amount_usd                                   NaN  1.000000
# crowd_equity_pre_money_valuation_usd                             NaN       NaN
# crowd_equity_post_money_valuation_usd                            NaN       NaN
# crowd_equity_participants                                        NaN       NaN
# age                                                              NaN  1.000000
#
# [83 rows x 83 columns]

# %%
f, ax = plt.subplots(figsize=(14, 11))
sns.heatmap(corrmat, vmax=.8, square=True);

# %% [markdown]
# Columns which have the absolute value of correlation between them more than 0.6

# %%
threshold = 0.6
index = corrmat.index
for i in range(len(index)):
    for j in range(i + 1, len(index)):
        corr_value = corrmat.loc[index[i], index[j]]
        if abs(corr_value) > threshold and corr_value != 1:
            print("%s <-> %s: %s" % (index[i], index[j], corr_value))
# Out:
# valuation_amount <-> raised_amount: 0.994551768605
# valuation_amount <-> angel_raised_amount_usd: -1.0
# valuation_amount <-> unattributed_raised_amount_usd: 0.632402232222
# valuation_amount <-> debt_round_raised_amount_usd: 0.899794706115
# valuation_amount <-> f_raised_amount_usd: 0.854394480812
# valuation_amount <-> grant_raised_amount_usd: 0.989149313097
# valuation_amount <-> post_ipo_equity_raised_amount_usd: -1.0
# raised_amount <-> d_raised_amount_usd: 0.811102860111
# raised_amount <-> unattributed_raised_amount_usd: 0.986356291555
# raised_amount <-> f_raised_amount_usd: 0.912203851352
# raised_amount <-> private_equity_raised_amount_usd: 0.647419332096
# raised_amount <-> post_ipo_equity_raised_amount_usd: 0.961131353848
# raised_amount <-> post_ipo_equity_participants: 0.950303909275
# raised_amount <-> partial_raised_amount_usd: 0.797854367206
# b_raised_amount_usd <-> b_pre_money_valuation_usd: 0.872853462479
# b_raised_amount_usd <-> a_pre_money_valuation_usd: 0.686417745343
# b_raised_amount_usd <-> seed_post_money_valuation_usd: 0.951599681965
# b_raised_amount_usd <-> c_post_money_valuation_usd: 0.878970282803
# b_raised_amount_usd <-> d_post_money_valuation_usd: 0.986108610728
# b_pre_money_valuation_usd <-> b_post_money_valuation_usd: 0.99624611818
# b_pre_money_valuation_usd <-> angel_raised_amount_usd: -0.639823606633
# b_pre_money_valuation_usd <-> a_raised_amount_usd: 0.847081672242
# b_post_money_valuation_usd <-> angel_raised_amount_usd: 0.664186360585
# b_post_money_valuation_usd <-> angel_participants: 0.630952495885
# b_post_money_valuation_usd <-> a_raised_amount_usd: 0.658877054313
# b_post_money_valuation_usd <-> seed_raised_amount_usd: 0.918019976138
# b_post_money_valuation_usd <-> c_raised_amount_usd: 0.953102148984
# b_post_money_valuation_usd <-> d_raised_amount_usd: 0.860720074717
# b_post_money_valuation_usd <-> unattributed_raised_amount_usd: -1.0
# b_post_money_valuation_usd <-> unattributed_participants: -1.0
# b_participants <-> angel_post_money_valuation_usd: 0.631043603369
# b_participants <-> c_pre_money_valuation_usd: -1.0
# b_participants <-> g_raised_amount_usd: 0.632492522093
# b_participants <-> g_participants: 0.670873542875
# angel_raised_amount_usd <-> a_pre_money_valuation_usd: -1.0
# angel_raised_amount_usd <-> seed_post_money_valuation_usd: 0.746339230339
# angel_raised_amount_usd <-> unattributed_post_money_valuation_usd: 0.998330899898
# angel_raised_amount_usd <-> e_participants: -0.922017947775
# angel_raised_amount_usd <-> private_equity_raised_amount_usd: 0.857094343074
# angel_raised_amount_usd <-> convertible_raised_amount_usd: 0.897882182953
# angel_post_money_valuation_usd <-> a_raised_amount_usd: 0.740115756019
# angel_post_money_valuation_usd <-> a_post_money_valuation_usd: 0.904194430179
# angel_post_money_valuation_usd <-> seed_post_money_valuation_usd: 0.866895166411
# angel_post_money_valuation_usd <-> c_participants: -1.0
# angel_post_money_valuation_usd <-> unattributed_raised_amount_usd: 0.999929616165
# angel_post_money_valuation_usd <-> debt_round_participants: -1.0
# angel_post_money_valuation_usd <-> grant_raised_amount_usd: 0.698680274952
# angel_post_money_valuation_usd <-> grant_participants: 0.694141592407
# angel_participants <-> c_post_money_valuation_usd: 0.902389268263
# angel_participants <-> e_raised_amount_usd: 0.968198813719
# angel_participants <-> e_participants: 0.797573412306
# angel_participants <-> convertible_raised_amount_usd: 0.780241193188
# angel_participants <-> crowd_raised_amount_usd: 0.754854486201
# a_raised_amount_usd <-> a_pre_money_valuation_usd: 0.729814530035
# a_raised_amount_usd <-> a_post_money_valuation_usd: 0.883488147785
# a_raised_amount_usd <-> c_post_money_valuation_usd: 0.76003221861
# a_raised_amount_usd <-> d_post_money_valuation_usd: 0.976750318924
# a_raised_amount_usd <-> unattributed_post_money_valuation_usd: 0.995390504224
# a_raised_amount_usd <-> debt_round_post_money_valuation_usd: 0.938590522777
# a_raised_amount_usd <-> private_equity_post_money_valuation_usd: 1.0
# a_raised_amount_usd <-> convertible_raised_amount_usd: 0.914683818344
# a_raised_amount_usd <-> g_participants: 0.945816022097
# a_raised_amount_usd <-> secondary_market_raised_amount_usd: -1.0
# a_pre_money_valuation_usd <-> a_post_money_valuation_usd: 0.993233368391
# a_pre_money_valuation_usd <-> seed_participants: -0.67193194396
# a_pre_money_valuation_usd <-> c_raised_amount_usd: 0.802895647301
# a_pre_money_valuation_usd <-> d_raised_amount_usd: 0.775177409581
# a_pre_money_valuation_usd <-> unattributed_raised_amount_usd: 0.999991418276
# a_post_money_valuation_usd <-> seed_raised_amount_usd: 0.917438101305
# a_post_money_valuation_usd <-> c_raised_amount_usd: 0.873267648011
# a_post_money_valuation_usd <-> debt_round_raised_amount_usd: 0.834196937196
# a_post_money_valuation_usd <-> e_raised_amount_usd: -1.0
# a_post_money_valuation_usd <-> e_participants: -1.0
# a_participants <-> c_pre_money_valuation_usd: -1.0
# a_participants <-> debt_round_post_money_valuation_usd: -0.999823268971
# a_participants <-> g_raised_amount_usd: 0.984639004611
# a_participants <-> g_participants: 0.823398860346
# seed_raised_amount_usd <-> unattributed_post_money_valuation_usd: -1.0
# seed_raised_amount_usd <-> f_participants: -0.760723333955
# seed_raised_amount_usd <-> private_equity_post_money_valuation_usd: 0.986625236381
# seed_raised_amount_usd <-> private_equity_participants: 0.666313928004
# seed_raised_amount_usd <-> post_ipo_equity_raised_amount_usd: 0.790424130709
# seed_post_money_valuation_usd <-> unattributed_raised_amount_usd: 0.805223377278
# seed_post_money_valuation_usd <-> private_equity_raised_amount_usd: -1.0
# seed_post_money_valuation_usd <-> private_equity_post_money_valuation_usd: -1.0
# seed_post_money_valuation_usd <-> private_equity_participants: -1.0
# seed_post_money_valuation_usd <-> grant_post_money_valuation_usd: 0.760770918899
# seed_post_money_valuation_usd <-> crowd_raised_amount_usd: -1.0
# seed_participants <-> f_raised_amount_usd: 0.910659415513
# seed_participants <-> partial_post_money_valuation_usd: -1.0
# seed_participants <-> crowd_participants: 0.605626978889
# c_raised_amount_usd <-> c_pre_money_valuation_usd: -1.0
# c_raised_amount_usd <-> c_post_money_valuation_usd: 0.924870291804
# c_raised_amount_usd <-> d_post_money_valuation_usd: 0.892066743291
# c_raised_amount_usd <-> e_post_money_valuation_usd: 0.978007725488
# c_raised_amount_usd <-> grant_raised_amount_usd: 0.803076287125
# c_raised_amount_usd <-> g_raised_amount_usd: 0.870186123297
# c_pre_money_valuation_usd <-> c_participants: -1.0
# c_pre_money_valuation_usd <-> age: -1.0
# c_post_money_valuation_usd <-> d_raised_amount_usd: 0.989289228476
# c_post_money_valuation_usd <-> d_post_money_valuation_usd: 0.999995331055
# c_post_money_valuation_usd <-> unattributed_raised_amount_usd: -1.0
# c_participants <-> e_post_money_valuation_usd: 0.717236727946
# c_participants <-> f_post_money_valuation_usd: -1.0
# d_raised_amount_usd <-> d_post_money_valuation_usd: 0.959132684016
# d_raised_amount_usd <-> e_raised_amount_usd: 0.683367785854
# d_raised_amount_usd <-> e_post_money_valuation_usd: 0.989535504683
# d_raised_amount_usd <-> private_equity_raised_amount_usd: 0.686409807016
# d_raised_amount_usd <-> post_ipo_equity_raised_amount_usd: 0.777724646071
# d_raised_amount_usd <-> g_raised_amount_usd: 0.996640590778
# d_raised_amount_usd <-> g_participants: 0.703050389235
# d_post_money_valuation_usd <-> unattributed_participants: -1.0
# d_post_money_valuation_usd <-> e_raised_amount_usd: 0.977838591339
# d_post_money_valuation_usd <-> e_participants: 0.979863710097
# d_participants <-> post_ipo_equity_participants: -0.981980506062
# unattributed_raised_amount_usd <-> unattributed_post_money_valuation_usd: 0.661501820667
# unattributed_raised_amount_usd <-> post_ipo_equity_post_money_valuation_usd: -1.0
# unattributed_raised_amount_usd <-> convertible_raised_amount_usd: 0.752252854744
# unattributed_raised_amount_usd <-> crowd_raised_amount_usd: 0.984388770623
# unattributed_participants <-> private_equity_post_money_valuation_usd: 0.90813596953
# unattributed_participants <-> post_ipo_equity_post_money_valuation_usd: -1.0
# unattributed_participants <-> convertible_participants: 0.824503202616
# unattributed_participants <-> g_raised_amount_usd: -0.763533162031
# debt_round_raised_amount_usd <-> debt_round_post_money_valuation_usd: 0.708393744858
# debt_round_raised_amount_usd <-> private_equity_raised_amount_usd: 0.675968850119
# debt_round_raised_amount_usd <-> g_participants: 0.658438850976
# debt_round_post_money_valuation_usd <-> debt_round_participants: 0.616171772952
# debt_round_participants <-> convertible_participants: 0.687184270936
# debt_round_participants <-> g_raised_amount_usd: 0.644905307841
# e_raised_amount_usd <-> e_post_money_valuation_usd: 0.999688453281
# e_raised_amount_usd <-> secondary_market_participants: 0.621681086934
# e_post_money_valuation_usd <-> age: -0.919033931793
# f_raised_amount_usd <-> grant_raised_amount_usd: -0.995760447258
# f_raised_amount_usd <-> g_raised_amount_usd: 0.842378528182
# f_post_money_valuation_usd <-> f_participants: -1.0
# f_participants <-> grant_raised_amount_usd: 0.704782653243
# private_equity_raised_amount_usd <-> private_equity_post_money_valuation_usd: 0.993226608734
# private_equity_raised_amount_usd <-> grant_raised_amount_usd: 0.859513419142
# private_equity_raised_amount_usd <-> post_ipo_equity_raised_amount_usd: 0.963184233932
# private_equity_raised_amount_usd <-> post_ipo_equity_participants: 0.828283298199
# private_equity_raised_amount_usd <-> crowd_raised_amount_usd: 0.767052360862
# private_equity_raised_amount_usd <-> crowd_participants: 0.939154659518
# private_equity_raised_amount_usd <-> g_raised_amount_usd: 0.999951505264
# private_equity_participants <-> post_ipo_equity_participants: -0.755928946018
# private_equity_participants <-> crowd_raised_amount_usd: -1.0
# grant_raised_amount_usd <-> grant_post_money_valuation_usd: 0.983850002407
# grant_participants <-> convertible_raised_amount_usd: -0.972659600569
# post_ipo_equity_raised_amount_usd <-> post_ipo_equity_post_money_valuation_usd: 0.758353518844
# post_ipo_equity_post_money_valuation_usd <-> age: 0.69281102643
# post_ipo_debt_raised_amount_usd <-> post_ipo_debt_participants: 0.912495126603
# post_ipo_debt_raised_amount_usd <-> age: -0.980014588359
# post_ipo_debt_participants <-> age: -0.914555798931
# partial_raised_amount_usd <-> partial_post_money_valuation_usd: 0.999010264011
# convertible_post_money_valuation_usd <-> convertible_participants: 0.752475416352
# convertible_post_money_valuation_usd <-> age: 0.782968583398
# secondary_market_raised_amount_usd <-> secondary_market_participants: -1.0
# secondary_market_raised_amount_usd <-> age: -1.0

# %% [markdown]
# As shown above, there is a lot of columns which have strong correlation between them, but it can be explained. The more some company was funded, for example, at round A, the more it will be funded at round B. The strong correlation is one more reason to make new features.

# %% [markdown]
# <H3>Making new features</H3>

# %% [markdown]
# Let's test the first approach: binary features inicating some round was or not.

# %%
#codes = ['b', 'angel', 'a', 'seed', 'c', 'd', 'unattributed', 'debt_round', 'e', 'f', 'private_equity', 'grant', 'post_ipo_equity', 'post_ipo_debt', 'partial', 'convertible', 'crowd', 'g', 'secondary_market', 'crowd_equity']
#suff = ['funded_at', 'raised_amount_usd', 'pre_money_valuation_usd', 'post_money_valuation_usd', 'participants']
#good_old_features = ['is_acquired', 'age', 'category_code']
#ew_binary_features = pd.DataFrame(data[good_old_features])
#for code in codes:
#    new_binary_features["was_%s" % code] = data
